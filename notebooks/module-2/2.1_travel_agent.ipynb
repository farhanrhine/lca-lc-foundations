# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="meta-llama/llama-4-maverick-17b-128e-instruct",
                        model_provider="groq",
                        temperature = 0,
                        max_retries=3,
                        timeout=60,
                        max_tokens=300
                        )

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[18], line 5
#       1 from langchain.messages import HumanMessage
#       3 config = {"configurable": {"thread_id": "1"}}
# ----> 5 response = await agent.ainvoke(
#       6     {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
#       7     config
#       8     )
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:3158, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3155 chunks: list[dict[str, Any] | Any] = []
#    3156 interrupts: list[Interrupt] = []
# -> 3158 async for chunk in self.astream(
#    3159     input,
#    3160     config,
#    3161     context=context,
#    3162     stream_mode=["updates", "values"]
#    3163     if stream_mode == "values"
#    3164     else stream_mode,
#    3165     print_mode=print_mode,
#    3166     output_keys=output_keys,
#    3167     interrupt_before=interrupt_before,
#    3168     interrupt_after=interrupt_after,
#    3169     durability=durability,
#    3170     **kwargs,
#    3171 ):
#    3172     if stream_mode == "values":
#    3173         if len(chunk) == 2:
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\main.py:2971, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2969 for task in await loop.amatch_cached_writes():
#    2970     loop.output_writes(task.id, task.writes, cached=True)
# -> 2971 async for _ in runner.atick(
#    2972     [t for t in loop.tasks.values() if not t.writes],
#    2973     timeout=self.step_timeout,
#    2974     get_waiter=get_waiter,
#    2975     schedule_task=loop.aaccept_push,
#    2976 ):
#    2977     # emit output
#    2978     for o in _output(
#    2979         stream_mode,
#    2980         print_mode,
#    (...)   2983         asyncio.QueueEmpty,
#    2984     ):
#    2985         yield o
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_runner.py:304, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     302 t = tasks[0]
#     303 try:
# --> 304     await arun_with_retry(
#     305         t,
#     306         retry_policy,
#     307         stream=self.use_astream,
#     308         configurable={
#     309             CONFIG_KEY_CALL: partial(
#     310                 _acall,
#     311                 weakref.ref(t),
#     312                 stream=self.use_astream,
#     313                 retry_policy=retry_policy,
#     314                 futures=weakref.ref(futures),
#     315                 schedule_task=schedule_task,
#     316                 submit=self.submit,
#     317                 loop=loop,
#     318             ),
#     319         },
#     320     )
#     321     self.commit(t, None)
#     322 except Exception as exc:
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\pregel\_retry.py:137, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     135         break
#     136     else:
# --> 137         return await task.proc.ainvoke(task.input, config)
#     138 except ParentCommand as exc:
#     139     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:705, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     703     # run in context
#     704     with set_config_context(config, run) as context:
# --> 705         input = await asyncio.create_task(
#     706             step.ainvoke(input, config, **kwargs), context=context
#     707         )
#     708 else:
#     709     input = await step.ainvoke(input, config, **kwargs)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:473, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     471         await run_manager.on_chain_end(ret)
#     472 else:
# --> 473     ret = await self.afunc(*args, **kwargs)
#     474 if self.recurse and isinstance(ret, Runnable):
#     475     return await ret.ainvoke(input, config)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1186, in create_agent.<locals>.amodel_node(state, runtime)
#    1173 request = ModelRequest(
#    1174     model=model,
#    1175     tools=default_tools,
#    (...)   1181     runtime=runtime,
#    1182 )
#    1184 if awrap_model_call_handler is None:
#    1185     # No async handlers - execute directly
# -> 1186     response = await _execute_model_async(request)
#    1187 else:
#    1188     # Call composed async handler with base handler
#    1189     response = await awrap_model_call_handler(request, _execute_model_async)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain\agents\factory.py:1157, in create_agent.<locals>._execute_model_async(request)
#    1154 if request.system_message:
#    1155     messages = [request.system_message, *messages]
# -> 1157 output = await model_.ainvoke(messages)
#    1158 if name:
#    1159     output.name = name
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\runnables\base.py:5561, in RunnableBindingBase.ainvoke(self, input, config, **kwargs)
#    5554 @override
#    5555 async def ainvoke(
#    5556     self,
#    (...)   5559     **kwargs: Any | None,
#    5560 ) -> Output:
# -> 5561     return await self.bound.ainvoke(
#    5562         input,
#    5563         self._merge_configs(config),
#    5564         **{**self.kwargs, **kwargs},
#    5565     )
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:421, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     411 @override
#     412 async def ainvoke(
#     413     self,
#    (...)    418     **kwargs: Any,
#     419 ) -> AIMessage:
#     420     config = ensure_config(config)
# --> 421     llm_result = await self.agenerate_prompt(
#     422         [self._convert_input(input)],
#     423         stop=stop,
#     424         callbacks=config.get("callbacks"),
#     425         tags=config.get("tags"),
#     426         metadata=config.get("metadata"),
#     427         run_name=config.get("run_name"),
#     428         run_id=config.pop("run_id", None),
#     429         **kwargs,
#     430     )
#     431     return cast(
#     432         "AIMessage", cast("ChatGeneration", llm_result.generations[0][0]).message
#     433     )
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1128, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1119 @override
#    1120 async def agenerate_prompt(
#    1121     self,
#    (...)   1125     **kwargs: Any,
#    1126 ) -> LLMResult:
#    1127     prompt_messages = [p.to_messages() for p in prompts]
# -> 1128     return await self.agenerate(
#    1129         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#    1130     )
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1086, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1073     if run_managers:
#    1074         await asyncio.gather(
#    1075             *[
#    1076                 run_manager.on_llm_end(
#    (...)   1084             ]
#    1085         )
# -> 1086     raise exceptions[0]
#    1087 flattened_outputs = [
#    1088     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[union-attr]
#    1089     for res in results
#    1090 ]
#    1091 llm_output = self._combine_llm_outputs([res.llm_output for res in results])  # type: ignore[union-attr]
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1339, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1337     result = generate_from_stream(iter(chunks))
#    1338 elif inspect.signature(self._agenerate).parameters.get("run_manager"):
# -> 1339     result = await self._agenerate(
#    1340         messages, stop=stop, run_manager=run_manager, **kwargs
#    1341     )
#    1342 else:
#    1343     result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\langchain_groq\chat_models.py:614, in ChatGroq._agenerate(self, messages, stop, run_manager, **kwargs)
#     609 message_dicts, params = self._create_message_dicts(messages, stop)
#     610 params = {
#     611     **params,
#     612     **kwargs,
#     613 }
# --> 614 response = await self.async_client.create(messages=message_dicts, **params)
#     615 return self._create_chat_result(response, params)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\groq\resources\chat\completions.py:941, in AsyncCompletions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     721 async def create(
#     722     self,
#     723     *,
#    (...)    780     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     781 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#     782     """
#     783     Creates a model response for the given chat conversation.
#     784
#    (...)    939       timeout: Override the client-level default timeout for this request, in seconds
#     940     """
# --> 941     return await self._post(
#     942         "/openai/v1/chat/completions",
#     943         body=await async_maybe_transform(
#     944             {
#     945                 "messages": messages,
#     946                 "model": model,
#     947                 "citation_options": citation_options,
#     948                 "compound_custom": compound_custom,
#     949                 "disable_tool_validation": disable_tool_validation,
#     950                 "documents": documents,
#     951                 "exclude_domains": exclude_domains,
#     952                 "frequency_penalty": frequency_penalty,
#     953                 "function_call": function_call,
#     954                 "functions": functions,
#     955                 "include_domains": include_domains,
#     956                 "include_reasoning": include_reasoning,
#     957                 "logit_bias": logit_bias,
#     958                 "logprobs": logprobs,
#     959                 "max_completion_tokens": max_completion_tokens,
#     960                 "max_tokens": max_tokens,
#     961                 "metadata": metadata,
#     962                 "n": n,
#     963                 "parallel_tool_calls": parallel_tool_calls,
#     964                 "presence_penalty": presence_penalty,
#     965                 "reasoning_effort": reasoning_effort,
#     966                 "reasoning_format": reasoning_format,
#     967                 "response_format": response_format,
#     968                 "search_settings": search_settings,
#     969                 "seed": seed,
#     970                 "service_tier": service_tier,
#     971                 "stop": stop,
#     972                 "store": store,
#     973                 "stream": stream,
#     974                 "temperature": temperature,
#     975                 "tool_choice": tool_choice,
#     976                 "tools": tools,
#     977                 "top_logprobs": top_logprobs,
#     978                 "top_p": top_p,
#     979                 "user": user,
#     980             },
#     981             completion_create_params.CompletionCreateParams,
#     982         ),
#     983         options=make_request_options(
#     984             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     985         ),
#     986         cast_to=ChatCompletion,
#     987         stream=stream or False,
#     988         stream_cls=AsyncStream[ChatCompletionChunk],
#     989     )
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\groq\_base_client.py:1762, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1748 async def post(
#    1749     self,
#    1750     path: str,
#    (...)   1757     stream_cls: type[_AsyncStreamT] | None = None,
#    1758 ) -> ResponseT | _AsyncStreamT:
#    1759     opts = FinalRequestOptions.construct(
#    1760         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1761     )
# -> 1762     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\lca-lc-foundations\.venv\Lib\site-packages\groq\_base_client.py:1576, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1573             await err.response.aread()
#    1575         log.debug("Re-raising status error")
# -> 1576         raise self._make_status_error_from_response(err.response) from None
#    1578     break
#    1580 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "tool call validation failed: parameters for tool search-flight did not match schema: errors: [`/returnDate`: does not match pattern '^\\\\d{2}\\\\/\\\\d{2}\\\\/\\\\d{4}$']", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '[\n  {\n    "name": "search-flight",\n    "parameters": {\n      "flyFrom": "San Francisco",\n      "flyTo": "Tokyo",\n      "departureDate": "31/03/2024",\n      "returnDate": "",\n      "cabinClass": "M",\n      "passengers": {\n        "adults": 1,\n        "children": 0,\n        "infants": 0\n      },\n      "sort": "date"\n    }\n  }\n]'}}
# During task with name 'model' and id '5faa11ec-e20c-7e6f-b1d4-ea2c99818ada'

# %%
from pprint import pprint

pprint(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 from pprint import pprint
# ----> 3 pprint(response)
#
# NameError: name 'response' is not defined

# %%
print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(response["messages"][-1].content)
#
# NameError: name 'response' is not defined
